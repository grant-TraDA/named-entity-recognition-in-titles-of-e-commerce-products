# %%
import os
import pandas as pd
import json
import re

PL_WDC_NORMALIZED_PATH = os.path.join(
    os.path.abspath(''),
    '../pl_wdc_normalized.json'
)

products = []
for line in open(PL_WDC_NORMALIZED_PATH, 'r'):
    products.append(json.loads(line))

# %%
import re

ner_data_sentences = []
ner_data_tags = []
i_count = 0


for product in products:
    title = product['title']
    title_split = product['title'].split()
    brand_split = product['brand'].split()
    n_brand = len(brand_split)
    n_title = len(title_split)

    product_ner_data_tags = ['O'] * n_title

    p = re.compile(r'\d+ [a-z]+')
    for m in p.finditer(title):
        first_position = title[:m.start()].count(' ')
        product_ner_data_tags[first_position] = 'B-ORG'
        product_ner_data_tags[first_position+1] = 'I-ORG'

    pos = title.find(product['brand'])
    if pos > -1:
        first_position = title[:pos].count(' ')
        for i_brand in range(n_brand):
            tag = 'B-PER'
            if i_brand > 0:
                tag = 'I-PER'
                i_count += 1
            product_ner_data_tags[first_position+i_brand] = tag

    ner_data_sentences.append(title_split)
    ner_data_tags.append(product_ner_data_tags)

print(f"i_count = {i_count}")



for sentence, tags in zip(ner_data_sentences, ner_data_tags):
    print(sentence)
    print(tags)
    print("# # # # #")
# Out:
# i_count = 380
# ['mola', 'ultra', 'chłonne', 'ręczniki', 'papierowe', '4', 'rolki']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['woolite', 'delicate', 'płyn', 'do', 'prania', 'do', 'delikatnych', 'tkanin', 'i', 'wełny']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['air', 'wick', 'life', 'scents', 'pachnące', 'patyczki', 'o', 'zapachu', 'tajemniczych', 'ogrodów', 'z', 'dzieciństwa', '30', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['tarczyn', 'sok', '100', 'pomarańcza']
# ['B-PER', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kubuś', 'play', 'napój', 'owocowy', 'woda', 'i', 'owoce', 'jabłko', 'cytryna']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['ludwik', 'care', 'płyn', 'do', 'mycia', 'paneli', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ręcznik', 'kuchenny', '2', 'warstwowy', 'celulozowy', '50', 'listków']
# ['O', 'O', 'B-ORG', 'I-ORG', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['tiger', 'nitro', 'gazowany', 'napój', 'energetyzujący', 'o', 'smaku', 'limonki', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ariel', 'allin1', 'pods', 'mountain', 'spring', 'kapsułki', 'do', 'prania', '14', 'prań']
# ['B-PER', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['woolite', 'pro', 'care', 'kapsułki', 'do', 'prania', '616', 'g', '28', 'x', '22', 'g']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['nałęczowianka', 'naturalna', 'woda', 'mineralna', 'delikatnie', 'gazowana', '0', '5', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['regina', 'błysk', 'ręcznik', 'do', 'mycia', 'szyb', 'i', 'powierzchni', 'szklanych']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['kubuś', 'sok', 'marchew', 'brzoskwinia', 'jabłko', '900', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['cif', 'perfect', 'finish', 'spray', 'do', 'czyszczenia', 'lodówek', 'i', 'mikrofalówek']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['air', 'wick', 'odświeżacz', 'elektryczny', 'i', 'wkład', 'księżycowa', 'lilia', 'otulona', 'satyną']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['clin', 'lemon', 'płyn', 'do', 'mycia', 'powierzchni', 'szklanych', 'opakowanie', 'uzupełniające', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fairy', 'płyn', 'do', 'mycia', 'naczyń', 'jabłko']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['glade', 'pure', 'clean', 'linen', 'odświeżacz', 'powietrza', 'w', 'aerozolu', '300', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['płyn', 'do', 'wc', 'o', 'zapachu', 'natury']
# ['O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['bref', 'wc', 'color', 'aktiv', 'zawieszka', 'do', 'muszli', 'wc', 'eukaliptus', '2', 'x', '50', 'g']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['finish', 'classic', 'tabletki', 'do', 'zmywania', 'naczyń', 'regular', '57', 'szt']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kret', 'żel', 'do', 'udrożniania', 'rur', '1', 'kg']
# ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['dosia', 'multi', 'powder', 'proszek', 'do', 'prania', 'tkanin', 'białych', '300', 'g', '4', 'prania']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['hortex', 'nektar', 'banan', '1', 'l']
# ['B-PER', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fanta', 'shokata', 'napój', 'gazowany', '500', 'ml']
# ['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['sprite', 'napój', 'gazowany', 'o', 'smaku', 'cytrynowo', 'limonkowym']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['seventh', 'generation', 'fresh', 'citrus', 'ginger', 'scent', 'płyn', 'do', 'mycia', 'naczyń', '500', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['vizir', 'alpine', 'fresh', 'płyn', 'do', 'prania', '2', '2', 'l', '40', 'prań']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['coccolino', 'care', 'kapsułki', 'do', 'prania', 'kolorowych', 'tkanin', '29', 'szt']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kiwi', 'express', 'shine', 'gąbka', 'nabłyszczająca', 'do', 'obuwia', 'brązowa', '7', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['perwoll', 'care', 'repair', 'płyn', 'do', 'prania', 'tkanin', 'białych', 'i', 'kolorowych']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['staropolanka', '2000', 'naturalna', 'woda', 'mineralna', 'wysokozmineralizowana', 'lekko', 'gazowana', '1', '5', 'l']
# ['B-PER', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['drwitt', 'premium', 'witalność', 'napój', 'multiwitamina', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['finish', 'quantum', 'ultimate', 'kapsułki', 'do', 'zmywarki', 'regular', '40', 'szt']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['bref', 'wc', 'deluxe', 'zawieszka', 'toaletowa', 'czarujący', 'jaśmin', '2', 'x', '50', 'g']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['perwoll', 'płyn', 'do', 'prania', '3', 'w', '1', 'renew', 'blossom']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG', 'O']
# # # # # #
# ['oshee', 'napój', 'izotoniczny', 'niegazowany', 'o', 'smaku', 'grejpfrutowym', '0', '75', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fairy', 'platinum', 'plus', 'all', 'in', 'one', 'regular', 'tabletki', 'do', 'zmywarki', 'x30']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['oshee', 'vitamin', 'energy', 'napój', 'gazowany', 'magnez', 'wit', 'b6', 'wit', 'b5']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O']
# # # # # #
# ['pronto', 'emulsja', 'do', 'mebli', '250', 'ml']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['morning', 'fresh', 'płyn', 'do', 'mycia', 'naczyń', 'cytrynowy']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['ace', 'ultra', 'silny', 'żel', 'flowers']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['powerade', 'zero', 'mountain', 'blast', 'napój', 'izotoniczny', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['coccolino', 'care', 'kapsułki', 'do', 'prania', 'czarnych', 'i', 'ciemnych', 'tkanin', '40', 'szt']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ariel', 'allin1', 'pods', 'color', 'kapsułki', 'do', 'prania', '26', 'prań']
# ['O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['pronto', 'jasmine', 'aerozol', 'przeciw', 'kurzowi', '300', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['odplamiacz', '1l']
# ['O', 'O']
# # # # # #
# ['fanta', 'orange', 'napój', 'gazowany']
# ['B-PER', 'O', 'O', 'O']
# # # # # #
# ['tymbark', 'jabłko', 'sok', '100']
# ['B-PER', 'O', 'O', 'O']
# # # # # #
# ['emulsyjna', 'pasta', 'do', 'obuwia', 'czarna']
# ['O', 'O', 'O', 'O', 'O']
# # # # # #
# ['regina', 'najdłuższy', 'ręcznik', 'uniwersalny', '2', 'rolki']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['coccolino', 'care', 'kapsułki', 'do', 'prania', 'kolorowych', 'tkanin', '40', 'szt']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['sady', 'wincenta', 'sok', 'jabłkowy', 'w', 'kartonie', 'tłoczony']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['hortex', 'sok', '100', 'pomarańcza', 'mango', 'pet']
# ['B-PER', 'O', 'B-ORG', 'I-ORG', 'O', 'O']
# # # # # #
# ['żywiec', 'zdrój', 'z', 'nutą', 'mango', 'i', 'pomarańczy']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['red', 'bull', 'napój', 'energetyczny', 'pobudzający']
# ['B-PER', 'I-PER', 'O', 'O', 'O']
# # # # # #
# ['hortex', 'vitaminka', 'sok', 'marchwiowo', 'jabłkowo', 'brzoskwiniowy']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['pur', 'sekrety', 'kucharza', 'apple', 'płyn', 'do', 'mycia', 'naczyń', '750', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['tymbark', 'nektar', 'czarna', 'porzeczka', '300', 'ml']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['wm', 'balsam', 'do', 'prania', 'tkanin', 'czarnych', '1l']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['staropolanka', '800', 'naturalna', 'woda', 'mineralna', 'średniozmineralizowana', 'gazowana', '330', 'ml']
# ['B-PER', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['żywiec', 'zdrój', 'black', 'tea', 'napój', 'herbaciany', 'cytryna', 'limonka']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['coca', 'cola', 'lime', 'napój', 'gazowany']
# ['B-PER', 'I-PER', 'O', 'O', 'O']
# # # # # #
# ['sidolux', 'uniwersalny', 'płyn', 'do', 'mycia', 'kwiat', 'orchidei', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['pepsi', 'max', 'napój', 'gazowany']
# ['B-PER', 'I-PER', 'O', 'O']
# # # # # #
# ['oshee', 'napój', 'izotoniczny', 'o', 'smaku', 'cytrynowym']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['monster', 'zero', 'ultra', 'violet', 'napój', 'energetyzujący', 'gazowany']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['herbapol', 'syrop', 'o', 'smaku', 'aroniowym', '420', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ariel', 'color', 'kapsułki', 'do', 'prania', 'tkanin', 'kolorowych', '33', 'szt']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['hortex', 'vitaminka', 'sok', 'marchwiowo', 'jabłkowo', 'malinowy']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['ajax', 'płyn', 'do', 'mycia', 'szyb', 'lemon']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['lenor', 'płyn', 'do', 'płukania', 'tkanin', 'emerald', 'ivory', 'flower']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['morning', 'fresh', 'raspberry', 'apple', 'skoncentrowany', 'płyn', 'do', 'mycia', 'naczyń', '900', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['lenor', 'unstoppables', 'sport', 'perełki', 'zapachowe', '210g']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['jan', 'niezbędny', 'zmywaki', 'profilowane', 'trio', '3', 'szt']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['somat', 'all', 'in', '1', 'extra', 'tabletki', 'do', 'zmywarki', '70', 'szt']
# ['B-PER', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['żywiec', 'zdrój', 'z', 'nutą', 'mango', 'i', 'pomarańczy']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['żywiec', 'zdrój', 'mocny', 'gaz', 'napój', 'gazowany', 'i', 'nuta', 'marakui', 'limonki', '1', '5', 'l']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['coca', 'cola', 'cherry', 'taste', 'napój', 'gazowany', '850', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['sidolux', 'uniwersalny', 'płyn', 'do', 'mycia', 'konwaliowy']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['ariel', 'allin1', 'pods', 'sensitive', 'kapsułki', 'do', 'prania', '33', 'szt']
# ['B-PER', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['vizir', 'proszek', 'do', 'prania', 'kolorowych', 'tkanin', '3', '825', 'kg', '51', 'prań']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['coccolino', 'creations', 'płyn', 'do', 'płukania', 'passion', 'flower', 'bergamot']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['tymbark', 'pomarańcza', 'z', 'mandarynką', 'nektar']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['tymbark', 'multiwitamina', 'classic', 'sok', '100', 'pet']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ace', 'ultra', 'silny', 'żel', 'lemon']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['ludwik', 'płyn', 'do', 'pielęgnacji', 'podłóg', 'drewnianych']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['bref', 'color', 'aktiv', 'zawieszka', 'do', 'wc', 'cytryna', '2x50g']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['żywiec', 'zdrój', 'niegazowany', 'szkło']
# ['B-PER', 'I-PER', 'O', 'O']
# # # # # #
# ['ludwik', 'płyn', 'do', 'mycia', 'paneli']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['fortuna', 'ww', 'sok', '100', 'pomidorowo', 'warzywny', 'bez', 'dodatku', 'soli', '300', 'ml']
# ['B-PER', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['surf', 'duokap', 'kapsułki', 'do', 'prania', 'białego', 'i', 'kolorowego', 'hawajski', 'sen', '42', 'szt']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['herbapol', 'owocowa', 'spiżarnia', 'syrop', 'owocowy', 'o', 'smaku', 'dzikiej', 'róży', '420', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['duck', 'extra', 'power', 'citrus', 'żel', 'do', 'czyszczenia', 'i', 'wybielania', 'toalet', '750', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ariel', 'allin1', 'pods', 'color', 'kapsułki', 'do', 'prania', '33', 'prań']
# ['B-PER', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['finish', 'all', 'in', '1', 'max', 'tabletki', 'do', 'mycia', 'naczyń', 'w', 'zmywarce', '848', 'g', '53', 'sztuki']
# ['B-PER', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['domestos', 'płyn', 'czyszcząco', 'dezynfekujący', 'citrus', 'fresh']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['bref', 'wc', 'power', 'aktiv', 'zawieszka', 'myjąco', 'zapachowa', 'do', 'muszli', 'wc', 'morska', 'bryza', '3', 'x', '50', 'g']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['napój', 'z', 'soku', 'ananasowego', 'pasteryzowany', 'metodą', 'flash']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['air', 'wick', 'citrus', 'wkład', 'do', 'automatycznego', 'odświeżacza', 'powietrza', '250', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['glade', 'zapas', 'do', 'elektrycznego', 'odświeżacza', 'powietrza', 'czysta', 'świeżość']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['finish', 'classic', 'tabletki', 'do', 'zmywarki', 'lemon', 'cytrynowe', '57', 'szt']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fanta', 'pomarańczowa', 'napój', 'gazowany', '850', 'ml']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['herbapol', 'owocowa', 'spiżarnia', 'syrop', 'wiśniowy']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['finish', 'płyn', 'do', 'czyszczenia', 'zmywarki', 'cytrynowy', '250', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['oshee', 'vitamin', 'h2o', 'napój', 'niegazowany', 'cytrynowo', 'pomarańczowy', 'magnez']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['sidolux', 'expert', 'środek', 'do', 'ochrony', 'i', 'nabłyszczania', 'pcv', 'i', 'linoleum']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['cif', 'mleczko', 'do', 'czyszczenia', 'normal']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['air', 'wick', 'wkład', 'do', 'automatycznego', 'odświeżacza', 'powietrza', 'orzeźwiająca', 'bawełna', 'kwiat', 'migdałowca', '250', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['płyn', 'do', 'naczyń', 'cytrynowy', '1l']
# ['O', 'O', 'O', 'O', 'O']
# # # # # #
# ['fairy', 'platinum', 'all', 'in', 'one', 'kapsułki', 'do', 'zmywarek', 'lemon', '18', 'szt']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ludwik', 'płyn', 'uniwersalny', 'super', 'połysk', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kropla', 'beskidu', 'naturalna', 'woda', 'mineralna', 'gazowana']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['bref', 'wc', 'hygienically', 'clean', 'shine', 'fresh', 'mist', 'środek', 'czyszczący', 'do', 'wc', '700', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['herbapol', 'na', 'zimno', 'herbata', 'czarna', 'brzoskwinia']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['coccolino', 'sensitive', 'płyn', 'do', 'płukania', 'tkanin', 'koncentrat', '1800', 'ml', '72', 'prania']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['bref', 'wc', '10xeffect', 'power', 'gel', 'protection', 'shield', 'płynny', 'środek', 'do', 'mycia', 'muszli', 'wc', '700', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['botanica', 'by', 'air', 'wick', 'wkład', 'do', 'elektrycznego', 'odświeżacza', 'karaibski', 'wetiwer', 'drzewo', 'sandałowe', '19', 'ml']
# ['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['żel', 'do', 'wc', 'cytrynowy', '750ml']
# ['O', 'O', 'O', 'O', 'O']
# # # # # #
# ['ajax', 'optimal', '7', 'multi', 'action', 'płyn', 'do', 'szyb', '500', 'ml']
# ['B-PER', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['cif', 'mleczko', 'do', 'czyszczenia', 'lila']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['silan', 'fresh', 'sky', 'płyn', 'do', 'zmiękczania', 'tkanin', '2775', 'ml', '111', 'prań']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['tymbark', 'sok', '100', 'pomidor', 'pet']
# ['B-PER', 'O', 'B-ORG', 'I-ORG', 'O']
# # # # # #
# ['nałęczowianka', 'naturalna', 'woda', 'mineralna', 'niegazowana']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['mleczko', 'do', 'czyszczenia', '430ml']
# ['O', 'O', 'O', 'O']
# # # # # #
# ['pur', 'sekrety', 'pielęgnacji', 'aloe', 'vera', 'płyn', 'do', 'mycia', 'naczyń', '750', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['air', 'wick', 'wkład', 'do', 'elektrycznego', 'odświeżacza', 'powietrza', 'księżycowa', 'lilia', 'otulona', 'satyną', '19', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['emsal', 'tuba', 'szampon', 'do', 'dywanów', 'i', 'wykładzin']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['fanta', 'pomarańczowa', 'napój', 'gazowany', '2', 'x', '1', '5', 'l']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['regina', 'blitz', 'ręcznik', 'papierowy', 'uniwersalny']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['black', 'sex', 'energy', 'gazowany', 'napój', 'energetyzujący', '250', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fortuna', 'napój', 'witalność', 'multiwitamina', 'z', 'zielonych', 'owoców', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['royal', 'apple', 'sok', 'jabłko', 'aronia', 'w', 'kartonie', 'tłoczony']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['glade', 'odświeżacz', 'powietrza', 'w', 'aerozolu', 'japoński', 'ogród']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['kinley', 'napój', 'gazowany', 'o', 'smaku', 'virgin', 'mojito']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['fuzetea', 'napój', 'o', 'smaku', 'cytrynowym', 'z', 'ekstraktem', 'z', 'zielonej', 'herbaty']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['syrop', 'o', 'smaku', 'owoców', 'leśnych', 'zawiera', 'cukier', 'i', 'substancje', 'słodzące', 'zawiera', 'źródło', 'fenyloalaniny']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['pepsi', 'napój', 'gazowany']
# ['B-PER', 'O', 'O']
# # # # # #
# ['s', 'pellegrino', 'naturalna', 'woda', 'mineralna', 'gazowana', '750', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['staropolanka', '800', 'naturalna', 'woda', 'mineralna', 'średniozmineralizowana', 'lekko', 'gazowana', '330', 'ml']
# ['B-PER', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kubuś', '100', 'malina', 'marchew', 'jabłko', 'sok']
# ['B-PER', 'B-ORG', 'I-ORG', 'O', 'O', 'O']
# # # # # #
# ['tymbark', 'napój', 'pomarańcza', 'brzoskwinia', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['bref', 'wc', 'deluxe', 'zawieszka', 'toaletowa', 'magiczny', 'kwiat', '2', 'x', '50', 'g']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['biały', 'jeleń', 'hipoalergiczny', 'płyn', 'do', 'prania', 'hypocare', '1', 'l', '12', 'prań']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['duck', 'extra', 'power', 'żel', 'do', 'toalet', 'piana', 'wybielacz', 'citrus']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['lenor', 'perfum', 'des', 'secrets', 'płyn', 'do', 'płukania', 'tkanin', 'charm']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['cisowianka', 'perlage', 'naturalna', 'woda', 'mineralna', 'musująca', 'niskosodowa', '700', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['hortex', 'napój', 'białe', 'winogrona']
# ['B-PER', 'O', 'O', 'O']
# # # # # #
# ['andros', 'sok', 'nfc', 'ananasowy']
# ['B-PER', 'O', 'O', 'O']
# # # # # #
# ['cappy', 'sok', 'pomarańczowy', '100', '330', 'ml']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['tymbark', 'napój', 'jabłko', 'wiśnia', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['minispray', 'z', 'aplikatorem', 'o', 'zapachu', 'kwitnącej', 'wiśni']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['herbapol', 'owocowa', 'spiżarnia', 'syrop', 'cytrynowy']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['vanish', 'oxi', 'action', 'pet', 'expert', 'piana', 'do', 'dywanów', 'i', 'tapicerek']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['kret', 'żel', 'do', 'udrożniania', 'rur', '500', 'g']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['cillit', 'bang', 'wybielanie', 'i', 'dezynfekcja', 'produkt', 'do', 'czyszczenia', 'i', 'dezynfekcji', 'muszli', 'toaletowej', '750', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['mr', 'muscle', 'hydraulik', 'żel', 'do', 'udrażniania', 'rur']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['kinley', 'bitter', 'lemon', 'napój', 'gazowany', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kret', 'granulki', 'do', 'udrożniania', 'rur', '400', 'g']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['cif', 'power', 'shine', 'spray', 'przeciw', 'tłuszczowi', '750', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['finish', 'płyn', 'nabłyszczający', '800', 'ml']
# ['B-PER', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['somat', 'płyn', 'nabłyszczający', 'do', 'zmywarek', 'z', 'efektem', 'wspomagania', 'suszenia', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['nestlé', 'pure', 'life', 'naturalna', 'woda', 'źródlana', 'niegazowana']
# ['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['żywiec', 'zdrój', 'mocny', 'gaz', 'i', 'nuta', 'grejfrut', 'i', 'pomarańcza']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['dettol', 'antybakteryjny', 'spray', 'do', 'powierzchni', 'o', 'zapachu', 'limonki', 'z', 'miętą']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['glade', 'odświeżacz', 'powietrza', 'cytrus']
# ['B-PER', 'O', 'O', 'O']
# # # # # #
# ['finish', 'quantum', 'ultimate', 'kapsułki', 'do', 'zmywarek', 'lemon', 'cytrynowe', '32', 'szt']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['oshee', 'vitamin', 'original', 'classic', 'gazowany', 'napój', 'energetyzujący', '250', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kubuś', 'sok', 'marchew', 'malina', 'jabłko', '900', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['sidolux', 'anti', 'bac', 'środek', 'uniwersalny', 'antybakteryjny', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kret', 'żel', 'do', 'udrażniania', 'rur']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['coca', 'cola', 'cherry', 'napój', 'gazowany']
# ['B-PER', 'I-PER', 'O', 'O', 'O']
# # # # # #
# ['ariel', 'mountain', 'spring', 'płyn', 'do', 'prania', '2', '2l', '40', 'prań']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fortuna', 'nektar', 'czarna', 'porzeczka', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['hortex', 'napój', 'jabłko', 'mięta', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['vizir', 'allin1', 'alpine', 'kapsułki', 'do', 'prania', 'białych', 'i', 'kolorowych', 'tkanin', '36', 'szt']
# ['B-PER', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['100', 'sok', 'ananasowy', 'pasteryzowany', 'wzbogacony', 'witaminą', 'c', 'zawiera', 'cukry', 'naturalnie', 'występujące', 'w', 'owocach']
# ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['fortuna', 'nektar', 'ananasowy', '1', 'l']
# ['B-PER', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['vanish', 'oxi', 'action', 'odplamiacz', 'do', 'tkanin', 'w', 'płynie', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['hortex', 'vitaminka', 'sok', 'truskawka', 'marchew', 'jabłko', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['łowicz', 'syrop', 'o', 'smaku', 'pomarańczowym', '400', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['sidolux', 'uniwersalny', 'płyn', 'do', 'mycia', 'konwaliowy', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['mola', 'complex', 'ręcznik', 'papierowy', '3', 'w', '1']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O']
# # # # # #
# ['bref', 'wc', 'pronature', 'zawieszka', 'do', 'muszli', 'wc', 'mięta', 'i', 'eukaliptus', '2', 'x', '50', 'g']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['mola', 'extra', 'strong', 'ręczniki', 'papierowe', '2', 'rolki']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['płyn', 'do', 'mycia', 'naczyń', 'o', 'zapachu', 'miętowym']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['finish', 'classic', 'lemon', 'tabletki', 'do', 'zmywarki', '912', 'g', '57', 'sztuk']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['sidolux', 'ochrona', 'i', 'połysk', 'środek', 'do', 'podłóg', 'pvc', 'linoleum', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['air', 'wick', 'life', 'scents', 'pachnące', 'patyczki', 'świeżość', 'letniego', 'poranka', '30', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ajax', 'proszek', 'do', 'czyszczenia', 'cytrynowy']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['kropla', 'beskidu', 'naturalna', 'woda', 'mineralna', 'niegazowana', 'sport', 'cup']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['lenor', 'silk', 'tree', 'blossom', 'płyn', 'do', 'płukania', 'tkanin', '1', '38l', '46', 'prań']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kostki', 'do', 'wc', 'o', 'zapachu', 'morskim']
# ['O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['bref', 'perfume', 'switch', 'zawieszka', 'do', 'wc', 'słodka', 'brzoskwinia', 'czerwone', 'jabłko', '2x50g']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['powerade', 'napój', 'izotoniczny', 'mountain', 'blast']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['kubuś', 'go', 'sok', 'marchew', 'brzoskwinia', 'jabłko', '300', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['perwoll', 'care', 'condition', 'płynny', 'środek', 'do', 'prania', '1', '8', 'l', '30', 'prań']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['kinley', 'napój', 'gazowany', 'o', 'smaku', 'cytrynowym']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['pur', 'sekrety', 'kucharza', 'lemon', 'extra', 'płyn', 'do', 'mycia', 'naczyń', '750', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['silan', 'aromatheraphy', 'płyn', 'do', 'zmiękczania', 'tkanin', 'sensual', 'rose']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['oshee', 'for', 'runners', 'napój', 'izotoniczny', 'niegazowany', 'o', 'smaku', 'pomarańczowym', '0', '75', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['e', 'aromaterapia', 'proszek', 'do', 'prania', 'kwiat', 'lotosu', 'z', 'bali', 'i', 'lilia', '3', '9', 'kg', '60', 'prań']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['łowicz', 'syrop', 'o', 'smaku', 'pomarańczowym']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['pur', 'sekrety', 'świata', 'płyn', 'do', 'mycia', 'naczyń', 'malina', 'i', 'czerwona', 'porzeczka']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['ariel', 'color', 'style', 'proszek', 'do', 'prania', '3', '375kg', '45', 'prań']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['nektar', 'z', 'mango', 'na', 'bazie', 'częściowo', 'zagęszczonego', 'soku', 'pasteryzowany', 'zawartość', 'owoców', 'minimum', '30']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['fanta', 'pomarańczowa', 'napój', 'gazowany', '500', 'ml']
# ['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fairy', 'płyn', 'do', 'mycia', 'naczyń', 'rumiankowy', 'z', 'witaminą', 'e']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['herbapol', 'aktywność', 'napój', 'niegazowany', 'owocowo', 'ziołowy', 'mięta', 'mango', 'żeń', 'szeń', 'pet']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['pepsi', 'max', 'napój', 'gazowany', '1', '5', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['somat', 'lemon', 'lime', 'płyn', 'nabłyszczający', 'do', 'zmywarek', '750', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['hortex', 'nektar', 'czarna', 'porzeczka', '300', 'ml']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['bref', 'deluxe', 'zawieszka', 'do', 'wc', 'delikatna', 'magnolia', '2x50g']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['fairy', 'sensitive', 'aloes', 'i', 'jaśmin', 'płyn', 'do', 'mycia', 'naczyń', '1', '35', 'l']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['vanish', 'oxi', 'action', 'odplamiacz', 'do', 'tkanin', 'w', 'płynie']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['nestea', 'napój', 'herbaciany', 'o', 'smaku', 'brzoskwiniowym']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['domestos', 'płyn', 'do', 'dezynfekcji', 'pine', 'fresh']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['kubuś', 'marchew', 'brzoskwinia', 'jabłko', 'sok', 'z', 'warzyw', 'i', 'owoców']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['uzdrowisko', 'wysowa', 'franciszek', 'lecznicza', 'woda', 'mineralna', '500', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['coca', 'cola', 'zero', 'napój', 'gazowany']
# ['B-PER', 'I-PER', 'O', 'O', 'O']
# # # # # #
# ['wm', 'balsam', 'do', 'prania', 'tkanin', 'kolorowych', '1l']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['7', 'up', 'napój', 'gazowany']
# ['B-PER', 'I-PER', 'O', 'O']
# # # # # #
# ['persil', 'color', 'żel', 'do', 'prania', '3', '00', 'l', '60', 'prań']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['perwoll', 'wool', 'silk', 'płyn', 'do', 'prania', 'wełny', 'i', 'tkanin', 'delikatnych']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['oshee', 'vitamin', 'zero', 'magnez', 'napój', 'gazowany', 'o', 'smaku', 'jagód', 'acai', 'miechunki', 'peruwiańskiej', '250', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kostka', 'wc', 'cytrynowa', '40g']
# ['O', 'O', 'O', 'O']
# # # # # #
# ['kubuś', '100', 'banan', 'marchew', 'jabłko', 'sok']
# ['B-PER', 'B-ORG', 'I-ORG', 'O', 'O', 'O']
# # # # # #
# ['raid', 'aktywne', 'zawieszki', 'na', 'mole', '12', 'sztuk']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['calgon', '2w1', 'acticlean', 'proszek', 'zmiękczacz', 'wody']
# ['B-PER', 'B-ORG', 'I-ORG', 'O', 'O', 'O']
# # # # # #
# ['hortex', 'sok', 'jabłkowy', '100', 'pet']
# ['B-PER', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['sanytol', 'płyn', 'czyszczący', 'i', 'dezynfekujący', 'do', 'łazienki', 'w', 'sprayu', 'eukaliptus', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['monster', 'energy', 'pipeline', 'punch', 'gazowany', 'napój', 'energetyczny', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['dobrowianka', 'woda', 'mineralna', 'lekko', 'gazowana']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['e', 'aromatherapy', 'color', 'płynny', 'środek', 'do', 'prania', 'malezyjska', 'orchidea', 'i', 'drzewo', 'sandałowe']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['powerade', 'lemon', 'napój', 'izotoniczny', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['cif', 'perfect', 'finish', 'specjalistyczny', 'spray', 'piekarnik', 'i', 'grill', '435', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['baby', 'zdrój', 'girl', 'woda', 'źródlana', 'niegazowana']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['kiwi', 'shine', 'nourish', 'cream', 'krem', 'do', 'obuwia', 'ciemny', 'brąz', '50', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['żywiec', 'zdrój', 'black', 'tea', 'napój', 'herbaciany', 'brzoskwinia', 'pomarańcza']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['kubuś', 'go', 'sok', 'marchew', 'jabłko', 'banan', 'truskawka', '300', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kubuś', 'waterrr', 'napój', 'o', 'smaku', 'jabłka', '1', '5', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['cisowianka', 'naturalna', 'niegazowana', 'woda', 'mineralna']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['płyn', 'do', 'mycia', 'naczyń', 'sensitive', '1l']
# ['O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['vanish', 'oxi', 'action', 'odplamiacz', 'do', 'białych', 'tkanin', 'w', 'płynie']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['pronto', 'aerozol', 'do', 'mebli', 'drewnianych', 'classic']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['herbapol', 'syrop', 'o', 'smaku', 'arbuz', 'mięta']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['perrier', 'woda', 'mineralna', 'naturalnie', 'gazowana']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['ariel', 'color', 'płyn', 'do', 'prania', 'tkanin', 'kolorowych']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['żywiec', 'zdrój', 'z', 'nutą', 'truskawki']
# ['B-PER', 'I-PER', 'O', 'O', 'O']
# # # # # #
# ['płyn', 'do', 'mycia', 'szyb', 'zapas']
# ['O', 'O', 'O', 'O', 'O']
# # # # # #
# ['tymbark', 'sok', '100', 'jabłko']
# ['B-PER', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['oshee', 'napój', 'izotoniczny', 'o', 'smaku', 'pomarańczowym']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['baby', 'zdrój', 'woda', 'źródlana', 'niegazowana']
# ['B-PER', 'I-PER', 'O', 'O', 'O']
# # # # # #
# ['presto', 'clean', 'ściereczki', 'czyszczące', 'do', 'toalet', '42', 'szt']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['lenor', 'unstoppables', 'perełki', 'zapachowe', 'do', 'prania', 'dreams']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['hortex', 'napój', 'pomarańcza', 'mango', 'pet']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['cappy', 'nektar', 'grejpfrutowy', '1', 'l']
# ['B-PER', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fairy', 'clean', 'fresh', 'pomarańcza', 'z', 'trawą', 'cytrynową', 'płyn', 'do', 'mycia', 'naczyń', '450', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['lipton', 'ice', 'tea', 'lemon', 'napój', 'niegazowany', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['garden', 'napój', 'pomarańcza', '2', 'l']
# ['B-PER', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['cif', 'max', 'power', 'mleczko', 'wybielające', 'spring', 'fresh']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['air', 'wick', 'essential', 'mist', 'wkład', 'do', 'automatycznego', 'odświeżacza', 'powietrza', 'energetyzujący', '20', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ariel', 'allin1', 'pods', 'oxi', 'kapsułki', 'do', 'prania', '24', 'prań']
# ['O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['pur', 'sekrety', 'pielęgnacji', 'dłonie', 'i', 'paznokcie', 'balsam', 'do', 'mycia', 'naczyń']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['fairy', 'sensitive', 'płyn', 'do', 'mycia', 'naczyń', 'rumiankowy', 'z', 'witaminą', 'e']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['cillit', 'bang', 'odtłuszczanie', 'bez', 'szorowania', 'spray', '750', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kinley', 'virgin', 'mojito', 'napój', 'gazowany', '250', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['nestea', 'napój', 'herbaciany', 'o', 'smaku', 'brzoskwiniowym', '0', '5', 'l']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['hortex', 'nektar', 'czarna', 'porzeczka', '2', 'l']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['4move', 'napój', 'izotoniczny', 'niegazowany', 'o', 'smaku', 'cytrynowym', '0', '75', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['tymbark', 'jabłko', 'gruszka', 'napój', 'owocowy', 'pet']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['bref', 'deluxe', 'zawieszka', 'do', 'wc', 'delikatna', 'magnolia', '50g']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['dawtona', 'sok', 'z', 'buraków', 'z', 'jabłkiem', '330', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['cif', 'power', 'shine', 'płyn', 'do', 'czyszczenia', 'wybielający', 'spray']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['fortuna', 'sok', '100', 'jabłko', '1', 'l']
# ['B-PER', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['fortuna', 'uroda', 'czerwony', 'grejpfrut', 'sok', '1', 'l']
# ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['izo', 'proszek', 'czyszczący', 'cytryna', '500', 'g']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['napój', 'przecierowy', 'z', 'marchwi', 'truskawek', 'i', 'jabłek', 'wzbogacony', 'witaminą', 'c', 'słodzony', 'pasteryzowany']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['royal', 'apple', 'napój', 'jabłkowo', 'miętowy', '3', 'l']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kinley', 'napój', 'gazowany', 'o', 'smaku', 'cytrynowym']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['fairy', 'granat', 'płyn', 'do', 'mycia', 'naczyń', '1', '8', 'l']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['velvet', 'ręcznik', 'papierowy', 'extra', 'long', 'decor', 'a', '2', '1']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['vizir', 'sensitive', 'proszek', 'do', 'prania', '3', '825kg', '51', 'prań']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['nestea', 'ice', 'tea', 'napój', 'herbaciany', 'o', 'smaku', 'cytrynowym']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['ręcznik', 'papierowy', 'mega', 'rolka', '500', 'listków']
# ['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['pur', 'sekrety', 'pielęgnacji', 'hands', 'nails', 'płyn', 'do', 'mycia', 'naczyń', '750', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kropla', 'beskidu', 'naturalna', 'woda', 'mineralna', 'niegazowana']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['cisowianka', 'naturalna', 'woda', 'mineralna', 'gazowana']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['morning', 'fresh', 'sensitive', 'aloe', 'vera', 'skoncentrowany', 'płyn', 'do', 'mycia', 'naczyń', '450', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['lenor', 'płyn', 'do', 'płukania', 'tkanin', 'diamond', 'lotus', 'flower']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['woolite', 'czerń', 'ciemne', 'kolory', 'jeans', 'z', 'keratyną', 'płyn', 'do', 'prania', '4', '5', 'l', '75', 'prań']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['frosch', 'ecological', 'malinowy', 'płyn', 'do', 'wc', '750', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['frosch', 'ecological', 'cytrynowy', 'środek', 'do', 'kabin', 'prysznicowych', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['finish', 'all', 'in', '1', 'max', 'shine', 'protect', 'skoncentrowany', 'żel', 'do', 'mycia', 'naczyń', 'w', 'zmywarce', '1', 'l']
# ['B-PER', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ariel', 'allin1', 'pods', 'unstoppables', 'kapsułki', 'do', 'prania', '24', 'prań']
# ['B-PER', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['staropolanka', 'zdrój', 'woda', 'źródlana', 'niskozmineralizowana', 'lekko', 'gazowana', '5', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['herbapol', 'owocowa', 'spiżarnia', 'syrop', 'z', 'pomarańcza']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['hortex', 'vitaminka', 'sok', 'brzoskwinia', 'marchew', 'jabłko', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['pepsi', 'max', 'napój', 'gazowany', 'bez', 'cukru']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['ace', 'ultra', 'fresh', 'silny', 'żel']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['fortuna', 'karotka', 'sok', 'marchew', 'witaminy', 'a', 'c', 'e', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['sok', 'ananasowy', '100', '1l']
# ['O', 'O', 'O', 'O']
# # # # # #
# ['silan', 'lavender', 'garden', 'płyn', 'do', 'zmiękczania', 'tkanin']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['kubuś', 'waterrr', 'napój', 'o', 'smaku', 'truskawki', '1', '5', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['herbapol', 'smaki', 'słońca', 'syrop', 'o', 'smaku', 'coli', '420', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['żel', 'punktowy', 'wc', 'cytryna', '75ml']
# ['O', 'O', 'O', 'O', 'O']
# # # # # #
# ['kiwi', 'express', 'shine', 'gąbka', 'nabłyszczająca', 'do', 'obuwia', 'brązowa', '7', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['odplamiacz', 'w', 'płynie', 'do', 'białego', '1l']
# ['O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['sidolux', 'crystal', 'lemon', 'płyn', 'do', 'mycia', 'szyb', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fairy', 'cytryna', 'płyn', 'do', 'mycia', 'naczyń', '450', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['sady', 'wincenta', 'sok', 'wieloowocowy', 'w', 'kartonie', 'tłoczony']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['air', 'wick', 'life', 'scents', 'pachnące', 'patyczki', 'wędrówka', 'leśną', 'ścieżką', '30', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['air', 'wick', 'freshmatic', 'life', 'scents', 'pachnące', 'patyczki', 'tajemniczny', 'ogród', 'z', 'dzieciństwa']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['hortex', 'nektar', 'bananowy']
# ['B-PER', 'O', 'O']
# # # # # #
# ['woolite', 'pro', 'care', 'kapsułki', 'do', 'prania', '28', 'szt']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fortuna', 'sok', '100', 'jabłko', '300', 'ml']
# ['B-PER', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['somat', 'classic', 'tabletki', 'do', 'zmywarek', '100', 'szt']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['frosch', 'nabłyszczacz', 'do', 'zmywarek']
# ['B-PER', 'O', 'O', 'O']
# # # # # #
# ['air', 'wick', 'pachnące', 'patyczki', 'świeżość', 'letniego', 'poranka']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['tymbark', 'nektar', 'czarna', 'porzeczka', 'pet']
# ['B-PER', 'O', 'O', 'O', 'O']
# # # # # #
# ['cillit', 'bang', 'power', 'cleaner', 'uniwersalny', 'środek', 'czyszczący', 'czystość', 'i', 'połysk', 'w', 'łazience']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['velvet', 'extra', 'long', 'decor', 'ręcznik', 'papierowy', '3', 'rolki']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['płyn', 'do', 'mycia', 'szyb']
# ['O', 'O', 'O', 'O']
# # # # # #
# ['somat', 'sól', 'do', 'zmywarek']
# ['B-PER', 'O', 'O', 'O']
# # # # # #
# ['coca', 'cola', 'napój', 'gazowany']
# ['B-PER', 'I-PER', 'O', 'O']
# # # # # #
# ['żywiec', 'zdrój', 'niegazowany', 'woda', 'źródlana', '6', 'x', '1', '5', 'l']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fuzetea', 'napój', 'o', 'smaku', 'cytrynowym', 'z', 'ekstraktem', 'z', 'zielonej', 'herbaty']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['air', 'wick', 'odświeżacz', 'elektryczny', 'i', 'wkład', 'białe', 'kwiaty']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['cillit', 'bang', 'czystość', 'i', 'połysk', 'w', 'łazience', 'spray', '750', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['nestlé', 'pure', 'life', 'woda', 'źródlana', 'niegazowana', '1', '5', 'l']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['glade', 'fresh', 'lemon', 'odświeżacz', 'powietrza', 'w', 'żelu', '150', 'g']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['sok', 'z', 'pomarańczy', 'brazylijskiej', '1l']
# ['O', 'O', 'O', 'O', 'O']
# # # # # #
# ['persil', 'proszek', 'do', 'prania', '3', '51', 'kg', '54', 'prania']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['ajax', 'boost', 'środek', 'czyszczący', 'ocet', 'lawenda', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fairy', 'platinum', 'płyn', 'do', 'mycia', 'naczyń']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['domestos', 'przedłużona', 'moc', 'citrus', 'fresh', 'płyn', 'czyszcząco', 'dezynfekujący', '750', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['żywiec', 'zdrój', 'ze', 'smakiem', 'truskawki']
# ['B-PER', 'I-PER', 'O', 'O', 'O']
# # # # # #
# ['dobrowianka', 'woda', 'mineralna', 'lekko', 'gazowana', '6', 'x', '1', '5', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['staropolanka', 'plus', 'naturalna', 'woda', 'mineralna', 'średniozmineralizowana', 'niegazowana', '0', '7', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['morning', 'fresh', 'lemon', 'skoncentrowany', 'płyn', 'do', 'mycia', 'naczyń', '900', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['vanish', 'color', 'protect', 'chusteczki', 'zapobiegające', 'farbowaniu', '20', 'prań', '10', 'sztuk']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['tiger', 'carbon', 'gazowany', 'napój', 'energetyzujący', '500', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fortuna', 'nektar', 'multiwitamina1', 'l']
# ['O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['okf', 'aloe', 'vera', 'king', 'original', 'napój', 'z', 'aloesu', '1', '5', 'l']
# ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['clin', 'płyn', 'do', 'mycia', 'powierzchni', 'szklanych', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['nestea', 'napój', 'herbaciany', 'o', 'smaku', 'brzoskwiniowym']
# ['B-PER', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['glade', 'odświeżacz', 'powietrza', 'lawenda']
# ['B-PER', 'O', 'O', 'O']
# # # # # #
# ['kubuś', '100', 'sok', 'banan', 'marchew', 'jabłko', '300', 'ml']
# ['B-PER', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kubuś', 'play', 'napój', 'z', 'marchwi', 'i', 'owoców', 'marchew', 'malina', 'jabłko', 'limetka', '400', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['somat', 'sól', 'do', 'zmywarek', '1', '5', 'kg']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ...
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['płyn', 'do', 'mycia', 'naczyń', 'miętowy', '1l']
# ['O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['herbapol', 'na', 'zimno', 'herbata', 'zielona', 'cytryna', 'mięta', '300', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ariel', 'color', 'reveal', 'płyn', 'do', 'prania', '2', '2l', '40', 'prań']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['garden', 'napój', 'pomarańcza', '2', 'l']
# ['B-PER', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['persil', 'discs', 'kapsułki', 'do', 'prania', '700', 'g', '28', 'prań']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['pur', 'sekrety', 'pielęgnacji', 'aloe', 'vera', 'płyn', 'do', 'mycia', 'naczyń', '750', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['lenor', 'unstoppables', 'dreams', 'perełki', 'zapachowe', '140', 'g']
# ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['tymbark', 'owoce', 'świata', 'napój', 'wieloowocowy', 'granat', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['presto', 'ściereczki', 'nawilżane', 'do', 'powierzchni', 'kamiennych', '16', 'sztuk']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['tymbark', 'napój', 'jabłko', 'wiśnia', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ajax', 'żel', 'do', 'łazienek', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['żywiec', 'zdrój', 'napój', 'niegazowany', 'z', 'nutą', 'brzoskwini', '1', '5', 'l']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['żywiec', 'zdrój', 'woda', 'źródlana', 'lekko', 'gazowana', '6', 'x', '1', '5', 'l']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['sok', 'marchwiowo', 'truskawekowo', 'jabłkowy', '750ml']
# ['O', 'O', 'O', 'O', 'O']
# # # # # #
# ['kubuś', 'waterrr', 'woda', 'niegazowana', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['herbapol', 'owocowa', 'spiżarnia', 'syrop', 'owocowy', 'czarna', 'porzeczka', '420', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['lenor', 'unstoppables', 'sport', 'wzmacniacz', 'zapachu', 'stosowany', 'podczas', 'prania', '210g']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['kiwi', 'shine', 'nourish', 'cream', 'krem', 'do', 'obuwia', 'ciemny', 'brąz', '50', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ręcznik', 'xxl', 'uniwersalny']
# ['O', 'O', 'O']
# # # # # #
# ['bryza', 'lanza', 'expert', 'white', 'proszek', 'do', 'prania', 'białych', 'tkanin', '9', '375', 'kg', '125', 'prań']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['e', 'skoncentrowany', 'płyn', 'do', 'zmiękczania', 'tkanin', 'różana', 'łąka', '2', 'l', '66', 'prania']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['tymbark', 'sok', '100', 'malina', 'jabłko', 'wiśnia', 'winogrono', '200', 'ml']
# ['B-PER', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fortuna', 'trawienie', 'pomidor', 'z', 'chili', 'sok', '100', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['dettol', 'antybakteryjne', 'chusteczki', 'do', 'mycia', 'powierzchni', '36', 'sztuk']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['vanish', 'proszek', 'do', 'prania', 'firanek', '400', 'g', '6', 'prań']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['coca', 'cola', 'lime', 'napój', 'gazowany', '500', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['wm', 'balsam', 'do', 'prania', '1', 'l']
# ['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ambi', 'pur', 'spring', 'awakening', 'odświeżacz', 'powietrza', 'w', 'sprayu']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['fortuna', 'sok', '100', 'jabłko', '1', 'l']
# ['B-PER', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['balsam', 'do', 'prania', 'tkanin', 'kolorowych']
# ['O', 'O', 'O', 'O', 'O']
# # # # # #
# ['kiwi', 'instant', 'shine', 'protect', 'pasta', 'nabłyszczająca', 'brązowa', '75', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ręcznik', 'papierowy', '4', 'rolki']
# ['O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['e', 'proszek', 'do', 'prania', 'górska', 'świeżość', '3', '9', 'kg', '60', 'prań']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['emsal', 'tuba', 'szampon', 'do', 'dywanów', 'i', 'wykładzin', '750', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['clin', 'apple', 'płyn', 'do', 'mycia', 'powierzchni', 'szklanych', 'opakowanie', 'uzupełniające', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['staropolanka', '2000', 'naturalna', 'woda', 'mineralna', 'wysokozmineralizowana', 'lekko', 'gazowana', '1', '5', 'l']
# ['B-PER', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['vizir', 'proszek', 'do', 'prania', 'kolorowych', 'tkanin', '3', '825', 'kg', '51', 'prań']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['kostka', 'barwiaca', 'do', 'wc', 'niebieska']
# ['O', 'O', 'O', 'O', 'O']
# # # # # #
# ['cisowianka', 'naturalna', 'woda', 'mineralna', 'lekko', 'gazowana', 'niskosodowa', '6', 'x', '1', '5', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['pepsi', 'napój', 'gazowany', '0', '85', 'l']
# ['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['zielko', 'płyn', 'do', 'szyb']
# ['B-PER', 'O', 'O', 'O']
# # # # # #
# ['hellena', 'oranżada', 'biała', '1', '25', 'l']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['żywiec', 'zdrój', 'black', 'tea', 'napój', 'niegazowany', 'czarna', 'herbata', 'brzoskwinia', 'pomarańcza', '1', '5', 'l']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['napój', 'przecierowy', 'z', 'marchwi', 'malin', 'i', 'jabłek', 'wzbogacony', 'witaminą', 'c', 'słodzony', 'pasteryzowany']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['żywiec', 'zdrój', 'mocny', 'gaz', 'woda', 'źródlana', '500', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['fairy', 'clean', 'fresh', 'granat', 'płyn', 'do', 'mycia', 'naczyń', '900', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['cillit', 'bang', 'żel', 'do', 'wc', 'kamień', 'i', 'rdza']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['vizir', 'color', 'proszek', 'do', 'prania', '4', 'prania', '300', 'g']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['vanish', 'gold', 'carpet', 'care', 'czyszczenie', 'ręczne', 'cytrynowy', 'szampon', 'do', 'dywanów', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['piwniczanka', 'naturalna', 'woda', 'mineralna', 'średnionasycona', 'co2', '1', '5', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['red', 'bull', 'napój', 'energetyczny', 'bez', 'cukru', '250', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['domestos', 'power', '5', 'pine', 'kostka', 'toaletowa', '3', 'x', '55', 'g']
# ['B-PER', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['royal', 'apple', 'sok', 'jabłkowy', '3', 'l']
# ['B-PER', 'I-PER', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['vizir', 'allin1', 'color', 'kapsułki', 'do', 'prania', '27', 'prań']
# ['O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['baby', 'zdrój', 'girl', 'woda', 'żródlana']
# ['B-PER', 'I-PER', 'O', 'O', 'O']
# # # # # #
# ['bryza', 'ekspert', 'żel', 'do', 'prania', 'tkanin', 'kolorowych']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['domestos', 'przedłużona', 'moc', 'biel', 'i', 'połysk', 'płyn', 'czyszcząco', 'dezynfekujący', '750', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['hortex', 'vitaminka', 'sok', 'marchewka', '300', 'ml']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['air', 'wick', 'pure', 'wkład', 'do', 'odświeżacza', 'powietrza', 'energetyzujący', '250', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kret', 'granulki', 'do', 'udrożniania', 'rur', '800', 'g']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['domestos', 'power', '5', 'fresh', 'orange', 'blossom', 'kostka', 'toaletowa', '55', 'g']
# ['B-PER', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['napój', 'aloe', 'vera', 'king', 'z', 'cząstkami', 'aloesu', '0', '5', 'l']
# ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['off', 'protect', 'repelent', 'przeciw', 'komarom', 'i', 'kleszczom', 'w', 'aerozolu', '100', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['cif', 'ultraszybki', 'łazienka', 'spray', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kropla', 'beskidu', 'naturalna', 'woda', 'mineralna', 'gazowana', '1', '5', 'l']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['andros', '100', 'sok', 'z', 'pomarańczy', 'wyciskanych', '1', 'l']
# ['O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['cisowianka', 'naturalna', 'woda', 'mineralna', 'niegazowana', 'niskosodowa', '700', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['herbapol', 'owocowa', 'spiżarnia', 'syrop', 'owocowy', 'malina', 'z', 'melisą', '420', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['domestos', 'power', '5', 'pine', 'kostka', 'toaletowa', '3', 'x', '55', 'g']
# ['B-PER', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['cif', 'power', 'shine', 'spray', 'przeciw', 'tłuszczowi', '750', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['duck', 'fresh', 'discs', 'marine', 'zapas', 'krążka', 'żelowego', 'do', 'toalety', '72', 'ml', '2', 'zapasy']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['sanytol', 'płyn', 'czyszczący', 'i', 'dezynfekujący', 'podłogi', 'i', 'inne', 'powierzchnie', 'eukaliptus', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['sok', 'ze', 'świeżych', 'ananasów', '1l']
# ['O', 'O', 'O', 'O', 'O']
# # # # # #
# ['ajax', 'floral', 'fiesta', 'płyn', 'do', 'szyb', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['monster', 'ripper', 'gazowany', 'napój', 'energetyzujący', '500', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['glade', 'sensual', 'sandalwood', 'jasmine', 'zapas', 'do', 'automatycznego', 'odświeżacza', 'powietrza', '269', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['cillit', 'bang', 'zero', 'kamienia', 'spray', '750', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kropla', 'beskidu', 'naturalna', 'woda', 'mineralna', 'niegazowana', '6', 'x', '1', '5', 'l']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['żel', 'do', 'wc', 'morski', '750ml']
# ['O', 'O', 'O', 'O', 'O']
# # # # # #
# ['bryza', 'lanza', 'expert', 'mix', 'color', 'proszek', 'do', 'prania', '4', '5', 'kg', '60', 'prań']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['pronto', 'lime', 'aerozol', 'przeciw', 'kurzowi', '300', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kubuś', '100', 'sok', 'multiwitamina', '300', 'ml']
# ['B-PER', 'B-ORG', 'I-ORG', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['powerade', 'zero', 'mountain', 'blast', 'napój', 'izotoniczny', '500', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kinley', 'tonic', 'water', 'napój', 'gazowany', '1', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['foxy', 'mega', 'ręcznik', 'kuchenny', '2', 'rolki']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['herbapol', 'syrop', 'owocowy', 'malina', '420', 'ml']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['hortex', 'nektar', 'czarna', 'porzeczka', '2', 'l']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['odświeżacz', 'powietrza', 'w', 'płynie', '2w1', 'lawenda', '375ml']
# ['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O']
# # # # # #
# ['fuzetea', 'napój', 'o', 'smaku', 'cytrynowym', 'z', 'ekstraktem', 'z', 'zielonej', 'herbaty', '1', '5', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kubuś', 'waterrr', 'woda', 'niegazowana', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['morning', 'fresh', 'apple', 'skoncentrowany', 'płyn', 'do', 'mycia', 'naczyń', '450', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['dettol', 'antybakteryjny', 'spray', 'do', 'powierzchni', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kinley', 'bitter', 'lemon', 'napój', 'gazowany', '250', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['air', 'wick', 'pure', 'kwitnąca', 'wiśnia', 'odświeżacz', 'powietrza', '250', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['burn', 'original', 'gazowany', 'napój', 'energetyczny', '250', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['hortex', 'napój', 'jabłko', 'mięta', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['nałęczowianka', 'naturalna', 'woda', 'mineralna', 'niegazowana', '0', '5', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['dobrowianka', 'woda', 'mineralna', 'lekko', 'gazowana', '6', 'x', '1', '5', 'l']
# ['B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['vanish', 'oxi', 'action', 'odplamiacz', 'do', 'białych', 'tkanin', 'w', 'płynie', '500', 'ml']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['dettol', 'power', 'fresh', 'wielofunkcyjny', 'spray', 'do', 'powierzchni', 'o', 'zapachu', 'limonki', 'i', 'cytryny', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['frosch', 'ecological', 'winogronowy', 'środek', 'do', 'kabin', 'prysznicowych', '500', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['oshee', 'vitamin', 'original', 'classic', 'gazowany', 'napój', 'energetyzujący', '250', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['mill', 'clean', 'płyn', 'czyszczący', 'podłogi', 'drewno', 'panele', '888ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# # # # # #
# ['fortuna', 'sok', '100', 'pomidor', '300', 'ml']
# ['B-PER', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['tymbark', 'sok', '100', 'pomarańcza', '300', 'ml']
# ['B-PER', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['tymbark', 'sok', '100', 'pikantny', 'pomidor', '1', 'l']
# ['B-PER', 'O', 'B-ORG', 'I-ORG', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['kiwi', 'express', 'shine', 'gąbka', 'nabłyszczająca', 'do', 'obuwia', 'czarna', '7', 'ml']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['coca', 'cola', 'zero', 'napój', 'gazowany', '200', 'ml']
# ['B-PER', 'I-PER', 'O', 'O', 'O', 'B-ORG', 'I-ORG']
# # # # # #
# ['ludwik', 'all', 'in', 'one', 'żel', 'do', 'zmywarek', '750', 'ml', '30', 'cykli', 'mycia']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG', 'O']
# # # # # #
# ['woolite', 'pro', 'care', 'płyn', 'do', 'prania', '3', '6', 'l', '60', 'prań']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #
# ['finish', 'quantum', 'max', 'kapsułki', 'do', 'mycia', 'naczyń', 'w', 'zmywarce', '697', '5', 'g', '45', 'sztuk']
# ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'B-ORG', 'I-ORG']
# # # # # #

# %%
output_count = len(ner_data_sentences)

RESULTS_PATH = os.path.join(os.path.abspath(''), "../ner_dataset")

parts = [
    {"label": "train", "start": 0.0, "end": 0.8},
    {"label": "test", "start": 0.8, "end": 1.0},
    {"label": "valid", "start": 0.8, "end": 1.0}
]

for part in parts:
    part_path = os.path.join(RESULTS_PATH, f"{part['label']}.txt")
    start = int(output_count * part['start'])
    end = int(output_count * part['end'])

    result_file = open(part_path, 'w+')

    for idx in range(start, end):
        data_sentence = ner_data_sentences[idx]
        data_tags = ner_data_tags[idx]
        for token, tag in zip(data_sentence, data_tags):
            result_file.write(f'{token}\t{tag}\n')
        result_file.write('\n')
    result_file.close()
